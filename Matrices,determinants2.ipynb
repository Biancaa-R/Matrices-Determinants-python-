# %% [markdown]
# <a href="https://colab.research.google.com/github/Biancaa-R/Matrices-Determinants/blob/main/Matrices%2Cdeterminants2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#inputing 2 matrices:

#matrice 1:

rows=int(input("Enter the number of rows of the matrice 1"))
coloumns=int(input("Enter the coloumns of the matrice 1"))
matrice=[]
rowan=[]

for i in range (0,rows):
    for j in range(0,coloumns):
        element=int(input("enter the element"))
        rowan.append(element)
    print("one row completed")
    matrice.append(rowan)
    rowan=[]

print("matrice 1 is \n")    
for ch in matrice:
    print(ch)
A=matrice

#matrice 2:

rows_=coloumns
coloumns_=int(input("Enter the coloumns of the matrice 2"))
rowan=[]
matrix=[]

for i in range (0,rows_):
    for j in range(0,coloumns_):
        element=int(input("enter the element"))
        rowan.append(element)
    print("one row completed")
    matrix.append(rowan)
    rowan=[]

print("Matrice 2 is\n")    
for ch in matrix:
    print(ch)

B=matrix

#creating empty frame:

result=[]
for i in range(0,rows): # rows of the first matrice
    for j in range(0,coloumns_): #coloums of the second matrice
    
        rowan.append(0)
    result.append(rowan)    
    rowan=[]
print("\n")
print("The frame work of result")
for ch in result:
    print(ch)
    

#Multiplication of the two matrices:
    
for i in range(len(A)):
    for j in range(len(B[0])):
        for k in range(len(B)):
            result[i][j] +=A[i][k]* B[k][j]

print("\n")
print("The product of the 2 matrices is \n")

for i in result:
    print(i)
# Out:
# Enter the number of rows of the matrice 1  5
# Enter the coloumns of the matrice 1  4
# enter the element1
# enter the element3
# enter the element4
# enter the element5
# one row completed
# enter the element8
# enter the element6
# enter the element7
# enter the element9
# one row completed
# enter the element2
# enter the element3
# enter the element5
# enter the element4
# one row completed
# enter the element2
# enter the element1
# enter the element3
# enter the element4
# one row completed
# enter the element2
# enter the element4
# enter the element5
# enter the element7
# one row completed
# matrice 1 is
#
# [1, 3, 4, 5]
# [8, 6, 7, 9]
# [2, 3, 5, 4]
# [2, 1, 3, 4]
# [2, 4, 5, 7]
# Enter the coloumns of the matrice 2  4
# enter the element1
# enter the element3
# enter the element4
# enter the element5
# one row completed
# enter the element5
# enter the element5
# enter the element5
# enter the element6
# one row completed
# enter the element3
# enter the element4
# ...

# %% [markdown]
# Explanation of matrice multiplication:
#
# a=3 x 2
# b=2 x 1
#
# ```
# # This is formatted as code
# for i in range(len(A)):
#     for j in range(len(B[0])):
#         for k in range(len(B)):
#             result[i][j] +=A[i][k]* B[k][j]
# ```
# i values= 0,1,2
#
# j values= 0
#
# k values=0,1
#
# i   j   k
# =========
#
# 0 0 0
#
# 1 0 0
#
# 2 0 0
#
# ========
#
# 0  0  1
#
# 1  0  1
#
# 2  0  1
#
# ```
# result(0,0) += a(0)(0)* b(0,0)
# result(1)(0)+=a(1)(0) *b(0)(0)
# result(2)(0)+=a(2)(0)* b(0,0)
#
# result(0,0)+=a(0,1)*b(1,0)
# result(1,0)+=a(1,1)*b(1,0)
# result(2,0)+= a(2,1)* b(1,0)
#
# a=[1,2]   b=[4]
# [2,4]       [3]
# [3,1]
#
# result= [0]
#         [0]
#         [0]
#
#         [4+6]      [10]
#         [8+12]     [20]
#         [12+3]     [15]
